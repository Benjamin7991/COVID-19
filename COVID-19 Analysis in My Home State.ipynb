# %%
import pandas as pd
import os
import datetime

# %% [markdown]
# # Lets first compile all data into single df

# %%
#df = pd.read_csv('./csse_covid_19_daily_reports_us/09-04-2020.csv')

#files = [file for file in os.listdir('./csse_covid_19_daily_reports_us')]

files=[f for f in os.listdir("./csse_covid_19_daily_reports_us") if f.endswith('.csv')]
all_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('./csse_covid_19_daily_reports_us/' + file)
    all_data = pd.concat([all_data, df])
    


all_data.tail()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 54     Washington             US  2020-04-25 06:32:46  47.4009 -121.4905
# 55  West Virginia             US  2020-04-25 06:32:46  38.4912  -80.9545
# 56      Wisconsin             US  2020-04-25 06:32:46  44.2685  -89.6165
# 57        Wyoming             US  2020-04-25 06:32:46  42.7560 -107.3025
# 58      Recovered             US  2020-04-25 06:32:46      NaN       NaN
#
#     Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 54      12977     722        NaN  12255.0  53.0     171.894387       160324.0
# 55       1010      32      439.0    978.0  54.0      76.341763        29811.0
# 56       5356     263        NaN   5093.0  55.0     103.506165        59929.0
# 57        473       7      321.0    466.0  56.0      95.125090         8045.0
# 58          0       0    99079.0 -99079.0   NaN            NaN            NaN
#
# ...

# %% [markdown]
# ## Combined all files in a dir into one csv file. Then, filtered out my state.

# %%
co_filtered = all_data[all_data['Province_State'] == 'Colorado']

# %%
co_filtered.to_csv('co_filtered.csv')

# %%
co_filtered.head()
# Out:
#   Province_State Country_Region         Last_Update      Lat     Long_  \
# 6       Colorado             US 2020-06-08 03:33:42  39.0598 -105.3111
# 6       Colorado             US 2020-06-07 03:53:50  39.0598 -105.3111
# 6       Colorado             US 2020-08-21 04:30:30  39.0598 -105.3111
# 6       Colorado             US 2020-08-22 04:30:29  39.0598 -105.3111
# 6       Colorado             US 2020-07-06 04:34:10  39.0598 -105.3111
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 6      27987    1527     4074.0  22386.0   8.0     485.992065       213014.0
# 6      27834    1527     4055.0  22252.0   8.0     483.335232       208277.0
# 6      54211    1903     5759.0  46549.0   8.0     941.369773       895207.0
# 6      54211    1910     5759.0  46542.0   8.0     941.369773       906693.0
# 6      34048    1701     4568.0  27779.0   8.0     591.240856       350717.0
#
#    People_Hospitalized  Mortality_Rate         UID ISO3  Testing_Rate  \
# ...

# %% [markdown]
# ## Combined all files in a dir into one csv file. Then, filtered out my state.

# %%
del co_filtered['Long_']
del co_filtered['Lat']
del co_filtered['UID']
del co_filtered['FIPS']

# %% [markdown]
# #### Deleted longtitude and latitude..^

# %%
co_filtered.head()
# Out:
#   Province_State Country_Region         Last_Update  Confirmed  Deaths  \
# 6       Colorado             US 2020-06-08 03:33:42      27987    1527
# 6       Colorado             US 2020-06-07 03:53:50      27834    1527
# 6       Colorado             US 2020-08-21 04:30:30      54211    1903
# 6       Colorado             US 2020-08-22 04:30:29      54211    1910
# 6       Colorado             US 2020-07-06 04:34:10      34048    1701
#
#    Recovered   Active  Incident_Rate  People_Tested  People_Hospitalized  \
# 6     4074.0  22386.0     485.992065       213014.0               4480.0
# 6     4055.0  22252.0     483.335232       208277.0               4472.0
# 6     5759.0  46549.0     941.369773       895207.0               6784.0
# 6     5759.0  46542.0     941.369773       906693.0               6797.0
# 6     4568.0  27779.0     591.240856       350717.0               5550.0
#
#    Mortality_Rate ISO3  Testing_Rate  Hospitalization_Rate
# ...

# %%
co_filtered.dtypes
# Out:
# Province_State                  object
# Country_Region                  object
# Last_Update             datetime64[ns]
# Confirmed                        int64
# Deaths                           int64
# Recovered                      float64
# Active                         float64
# Incident_Rate                  float64
# People_Tested                  float64
# People_Hospitalized            float64
# Mortality_Rate                 float64
# ISO3                            object
# Testing_Rate                   float64
# Hospitalization_Rate           float64
# dtype: object

# %%
#co_filtered['Last_Update'] = pd.to_datetime(co_filtered['Last_Update'])

# %%
#co_filtered['Month'] = co_filtered['Last_Update'].dt.month

# %% [markdown]
# ### Grouped by state ^

# %% [markdown]
# ### Removed territories leaving only states^

# %% [markdown]
# # Now lets visualize data

# %%
all_data.head()

# %%
import matplotlib.pyplot as plt

states = [state for state, df in all_data.groupby('State')]

plt.bar(states, results['Confirmed'])
plt.xlabel('States', size = 15)
plt.ylabel('Confirmed Cases (in )', size = 15)
plt.title('Covid-19 Cases per State', size = 15)
plt.xticks(size = 9, rotation= 85)
plt.yticks(size = 10)



plt.grid()
plt.show()
